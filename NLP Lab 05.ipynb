# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\23bce7267\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Regex Tagger
from nltk.tag import RegexpTagger
#Define regex pattern
patterns = [
    (r'.*ing$','VBG'),
    (r'.*ed$','VBD'),
    (r'.*es$','VBZ'),
    (r'.*s$','NNS'),
    (r'^[0-9]+$','CD'),
    (r'.*','NN')
]
regex_tagger = RegexpTagger(patterns)
sentence = "Dogs are running quickly"
tokens = nltk.word_tokenize(sentence)
tags = regex_tagger.tag(tokens)
print(tags)
# Out:
# [('Dogs', 'NNS'), ('are', 'NN'), ('running', 'VBG'), ('quickly', 'NN')]

# %%
from nltk.tag import RegexpTagger

patterns = [
(r'^\d+$', 'CD'), # Cardinal numbers
(r'\b(I|me|my|he|him|his|she|her|we|you|it|they)\b', 'PRP'), # pronouns
(r'\b(on|in|at|by|with|about|into|to)\b', 'IN'), #prepositions
(r'\b(and|or|but|also)\b', 'CC'), #Conjunctions
(r'\b(The|the|A|a|An|an)\b', 'DT'), # Determiners
(r'\b\w+able\b', 'JJ'), # Adjectives ending in 'able'
(r'.*ing$', 'VBG'), # Gerunds
(r'.*ed$', 'VBD'), # Past tense verbs
(r'.*es$', 'VBZ'), # 3rd person singular verbs
(r'.*ly$', 'RB'), # Adverbs
(r'.*', 'NN') # Default: Noun
]
regex_tagger = RegexpTagger(patterns)
sentence = "70 students are attending Natural language processing lab and they completed all the programs quickly."
tokens = nltk.word_tokenize(sentence)
tags = regex_tagger.tag(tokens)
print(tags)
# Out:
# [('70', 'CD'), ('students', 'NN'), ('are', 'NN'), ('attending', 'VBG'), ('Natural', 'NN'), ('language', 'NN'), ('processing', 'VBG'), ('lab', 'NN'), ('and', 'CC'), ('they', 'PRP'), ('completed', 'VBD'), ('all', 'NN'), ('the', 'DT'), ('programs', 'NN'), ('quickly', 'RB'), ('.', 'NN')]

# %%
#NER (Name Entity Recognition) Tagger
import nltk
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
sentence = "Barack Obama was born in Hawaii"
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
tree = nltk.ne_chunk(pos_tags)
print(tree)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\23bce7267\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\23bce7267\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\23bce7267\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\23bce7267\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\23bce7267\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Hawaii/NNP))

# %%
sentence = "70 students are attending Natural language processing lab and they completed all the programs quickly."
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
tree = nltk.ne_chunk(pos_tags)
print(tree)
# Out:
# (S
#   70/CD
#   students/NNS
#   are/VBP
#   attending/VBG
#   (ORGANIZATION Natural/NNP)
#   language/NN
#   processing/NN
#   lab/NN
#   and/CC
#   they/PRP
#   completed/VBD
#   all/PDT
#   the/DT
#   programs/NNS
#   quickly/RB
#   ./.)

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Using cached https://files.pythonhosted.org/packages/07/53/536941af8fbb5cb10a778f0dbd2a17b0f13e7ebfc11e67b154be60508fdf/spacy-3.8.2.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   Complete output from command C:\ProgramData\Anaconda3\python.exe C:\ProgramData\Anaconda3\lib\site-packages\pip install --ignore-installed --no-user --prefix C:\Users\23BCE7~4\AppData\Local\Temp\pip-build-env-nzbx4kao\overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools cython>=0.25,<3.0 cymem>=2.0.2,<2.1.0 preshed>=3.0.2,<3.1.0 murmurhash>=0.28.0,<1.1.0 thinc>=8.3.0,<8.4.0 "numpy>=2.0.0,<2.1.0; python_version < '3.9'" "numpy>=2.0.0,<2.1.0; python_version >= '3.9'":
#   Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#   Collecting setuptools
#     Using cached https://files.pythonhosted.org/packages/c7/42/be1c7bbdd83e1bfb160c94b9cafd8e25efc7400346cf7ccdbdb452c467fa/setuptools-68.0.0-py3-none-any.whl
#   Collecting cython<3.0,>=0.25
#     Using cached https://files.pythonhosted.org/packages/7e/26/9d8de10005fedb1eceabe713348d43bae1dbab1786042ca0751a2e2b0f8c/Cython-0.29.37-py2.py3-none-any.whl
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached https://files.pythonhosted.org/packages/f2/4a/1acd761fb6ac4c560e823ce40536a62f886f2d59b2763b5c3fc7e9d92101/cymem-2.0.11.tar.gz
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Installing backend dependencies: started
#     Installing backend dependencies: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting preshed<3.1.0,>=3.0.2
#     Using cached https://files.pythonhosted.org/packages/bf/34/eb4f5f0f678e152a96e826da867d2f41c4b18a2d589e40e1dd3347219e91/preshed-3.0.12.tar.gz
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     Complete output from command C:\ProgramData\Anaconda3\python.exe C:\ProgramData\Anaconda3\lib\site-packages\pip install --ignore-installed --no-user --prefix C:\Users\23BCE7~4\AppData\Local\Temp\pip-build-env-jj01pcg8\overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools cython>=0.28 cymem>=2.0.2,<2.1.0 murmurhash>=0.28.0,<1.1.0:
#     Collecting setuptools
#       Using cached https://files.pythonhosted.org/packages/c7/42/be1c7bbdd83e1bfb160c94b9cafd8e25efc7400346cf7ccdbdb452c467fa/setuptools-68.0.0-py3-none-any.whl
#     Collecting cython>=0.28
#       Using cached https://files.pythonhosted.org/packages/c2/fd/889d587f8dd8526e8c77823cee7cfa36ec172d9938db94b9996fdab399f8/Cython-3.0.12-cp37-cp37m-win_amd64.whl
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached https://files.pythonhosted.org/packages/f2/4a/1acd761fb6ac4c560e823ce40536a62f886f2d59b2763b5c3fc7e9d92101/cymem-2.0.11.tar.gz
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#       Installing backend dependencies: started
#       Installing backend dependencies: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting murmurhash<1.1.0,>=0.28.0
#       Using cached https://files.pythonhosted.org/packages/23/2e/88c147931ea9725d634840d538622e94122bceaf346233349b7b5c62964b/murmurhash-1.0.15.tar.gz
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'error'
#       Complete output from command C:\ProgramData\Anaconda3\python.exe C:\ProgramData\Anaconda3\lib\site-packages\pip install --ignore-installed --no-user --prefix C:\Users\23BCE7~4\AppData\Local\Temp\pip-build-env-z916xi3w\overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools cython>=3.1:
#       Collecting setuptools
#         Using cached https://files.pythonhosted.org/packages/c7/42/be1c7bbdd83e1bfb160c94b9cafd8e25efc7400346cf7ccdbdb452c467fa/setuptools-68.0.0-py3-none-any.whl
#       Collecting cython>=3.1
#         Could not find a version that satisfies the requirement cython>=3.1 (from versions: 0.9.6.5, 0.9.6.6, 0.9.6.7, 0.9.6.8, 0.9.6.10b0, 0.9.6.10, 0.9.6.10.1, 0.9.6.11b0, 0.9.6.11, 0.9.6.12, 0.9.6.13, 0.9.6.13.1, 0.9.6.14, 0.9.8, 0.9.8.1, 0.9.8.1.1, 0.10, 0.10.1, 0.10.2, 0.10.3, 0.11, 0.11.1, 0.11.2, 0.11.3, 0.12, 0.12.1, 0.13, 0.14, 0.14.1, 0.15, 0.15.1, 0.16, 0.17, 0.17.1, 0.17.2, 0.17.3, 0.17.4, 0.18, 0.19, 0.19.1, 0.19.2, 0.20, 0.20.1, 0.20.2, 0.21, 0.21.1, 0.21.2, 0.22, 0.22.1, 0.23, 0.23.1, 0.23.2, 0.23.3, 0.23.4, 0.23.5, 0.24, 0.24.1, 0.25, 0.25.1, 0.25.2, 0.26, 0.26.1, 0.27, 0.27.1, 0.27.2, 0.27.3, 0.28, 0.28.1, 0.28.2, 0.28.3, 0.28.4, 0.28.5, 0.28.6, 0.29, 0.29.1, 0.29.2, 0.29.3, 0.29.4, 0.29.5, 0.29.6, 0.29.7, 0.29.8, 0.29.9, 0.29.10, 0.29.11, 0.29.12, 0.29.13, 0.29.14, 0.29.15, 0.29.16, 0.29.17, 0.29.18, 0.29.19, 0.29.20, 0.29.21, 0.29.22, 0.29.23, 0.29.24, 0.29.25, 0.29.26, 0.29.27, 0.29.28, 0.29.29, 0.29.30, 0.29.31, 0.29.32, 0.29.33, 0.29.34, 0.29.35, 0.29.36, 0.29.37, 3.0.0b1, 3.0.0b2, 3.0.0b3, 3.0.0rc1, 3.0.0rc2, 3.0.0, 3.0.1, 3.0.2, 3.0.3, 3.0.4, 3.0.5, 3.0.6, 3.0.7, 3.0.8, 3.0.9, 3.0.10, 3.0.11, 3.0.12)
#       No matching distribution found for cython>=3.1
#
#       ----------------------------------------
#     Command "C:\ProgramData\Anaconda3\python.exe C:\ProgramData\Anaconda3\lib\site-packages\pip install --ignore-installed --no-user --prefix C:\Users\23BCE7~4\AppData\Local\Temp\pip-build-env-z916xi3w\overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools cython>=3.1" failed with error code 1 in None
#
#     ----------------------------------------
#   Command "C:\ProgramData\Anaconda3\python.exe C:\ProgramData\Anaconda3\lib\site-packages\pip install --ignore-installed --no-user --prefix C:\Users\23BCE7~4\AppData\Local\Temp\pip-build-env-jj01pcg8\overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools cython>=0.28 cymem>=2.0.2,<2.1.0 murmurhash>=0.28.0,<1.1.0" failed with error code 1 in None
#
#   ----------------------------------------
# Command "C:\ProgramData\Anaconda3\python.exe C:\ProgramData\Anaconda3\lib\site-packages\pip install --ignore-installed --no-user --prefix C:\Users\23BCE7~4\AppData\Local\Temp\pip-build-env-nzbx4kao\overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools cython>=0.25,<3.0 cymem>=2.0.2,<2.1.0 preshed>=3.0.2,<3.1.0 murmurhash>=0.28.0,<1.1.0 thinc>=8.3.0,<8.4.0 "numpy>=2.0.0,<2.1.0; python_version < '3.9'" "numpy>=2.0.0,<2.1.0; python_version >= '3.9'"" failed with error code 1 in None
# C:\ProgramData\Anaconda3\python.exe: No module named spacy

# %%
import spacy
# Load the English NLP model
nlp = spacy.load("en_core_web_sm")
# Input sentence
sentence = "Barack Obama was born in Hawaii and was elected president of the United States."
# Process the sentence
doc = nlp(sentence)
# Named Entity Recognition
for ent in doc.ents:
    print(ent.text, "->", ent.label_)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-83a93ec1d29f> in <module>
# ----> 1 import spacy
#       2 # Load the English NLP model
#       3 nlp = spacy.load("en_core_web_sm")
#       4 # Input sentence
#       5 sentence = "Barack Obama was born in Hawaii and was elected president of the United States."
#
# ModuleNotFoundError: No module named 'spacy'
